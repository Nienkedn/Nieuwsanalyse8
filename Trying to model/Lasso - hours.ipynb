# %%
import pandas as pd

from matplotlib import pyplot as plt

from sklearn.preprocessing import OneHotEncoder

from sklearn.linear_model import LinearRegression

import warnings

import csv

import datetime



warnings.filterwarnings('ignore')

pd.plotting.register_matplotlib_converters()

# %%
df = pd.read_csv('data2.csv', parse_dates=['Timestamp'], encoding = 'utf-16')

df.head()
# Out:
#     Origin   Timestamp                                            Content  \
# 0  twitter  1552760166  Mooi verhaal over windmolens https://www.insta...
# 1  twitter  1552995709  Het mooiste happy hour was afgelopen zaterdag....
# 2  twitter  1553001655  Dus bij jou in de achtertuin windmolensvoortui...
# 3  twitter  1552471319  Hoe kan provincie zorgen voor bouw van genoeg ...
# 4  twitter  1552993305  We zijn geen communistisch land. Een vliegveld...
#
#   Title  Comment_count  Retweet_count  Polarity  Subjectivity
# 0  Null            1.0            0.0      0.70          1.00
# 1  Null            0.0            0.0      0.00          0.00
# 2  Null            0.0            0.0      0.00          0.00
# 3  Null            0.0            0.0      0.20          0.50
# 4  Null            0.0            0.0      0.19          0.58

# %%
df['Timestamp']= pd.to_datetime(df['Timestamp'], unit='s')

df.head()
# Out:
#     Origin           Timestamp  \
# 0  twitter 2019-03-16 18:16:06
# 1  twitter 2019-03-19 11:41:49
# 2  twitter 2019-03-19 13:20:55
# 3  twitter 2019-03-13 10:01:59
# 4  twitter 2019-03-19 11:01:45
#
#                                              Content Title  Comment_count  \
# 0  Mooi verhaal over windmolens https://www.insta...  Null            1.0
# 1  Het mooiste happy hour was afgelopen zaterdag....  Null            0.0
# 2  Dus bij jou in de achtertuin windmolensvoortui...  Null            0.0
# 3  Hoe kan provincie zorgen voor bouw van genoeg ...  Null            0.0
# 4  We zijn geen communistisch land. Een vliegveld...  Null            0.0
#
#    Retweet_count  Polarity  Subjectivity
# 0            0.0      0.70          1.00
# 1            0.0      0.00          0.00
# 2            0.0      0.00          0.00
# 3            0.0      0.20          0.50
# 4            0.0      0.19          0.58

# %%
# load data


3


# remove outlier record

df = df.loc[df['Timestamp'] > '2007-01-01']

# FEATURE EXTRACTION

# month, for seasonality
df['month'] = 0
df['month'] = df['Timestamp'].dt.month
df['year'] = df['Timestamp'].dt.year

# days_since_first, for trend
df['days_since_first'] = 0
df['days_since_first'] = (df['Timestamp'] - min(df['Timestamp'])).dt.days



# create test design

train_filter = df['Timestamp'] < '2017-08-01'

df_train = df[train_filter]

df_test = df[(df['Timestamp'] > '2017-01-01') & (df['Timestamp'] < '2017-12-30')]

print(df_test)
# Out:
#       Origin           Timestamp  \
# 438  twitter 2018-07-29 06:30:00
# 439  twitter 2018-07-28 09:50:18
# 440  twitter 2018-07-27 15:19:38
# 442  twitter 2018-07-26 09:43:18
# 443  twitter 2018-07-24 09:34:32
# 444  twitter 2018-07-23 21:14:35
# 445  twitter 2018-07-23 08:17:08
# 446  twitter 2018-07-21 19:44:20
# 447  twitter 2018-07-21 18:29:44
# 450  twitter 2018-07-17 20:07:00
# 451  twitter 2018-07-17 10:06:20
# 452  twitter 2018-07-15 05:17:38
# 453  twitter 2018-07-14 09:17:34
# 454  twitter 2018-07-13 14:36:03
# 455  twitter 2018-07-12 13:24:44
# 456  twitter 2018-07-11 23:49:48
# 457  twitter 2018-07-11 21:19:37
# 459  twitter 2018-07-10 20:49:26
# 460  twitter 2018-07-10 19:03:23
# 461  twitter 2018-07-10 13:53:43
# 462  twitter 2018-07-08 10:38:35
# 463  twitter 2018-07-06 10:56:52
# 464  twitter 2018-07-05 21:27:34
# 465  twitter 2018-07-05 14:16:59
# 466  twitter 2018-07-04 08:35:44
# 467  twitter 2018-07-03 05:30:17
# 468  twitter 2018-06-26 11:01:15
# 469  twitter 2018-06-23 08:34:26
# 470  twitter 2018-06-22 16:23:59
# 471  twitter 2018-06-21 17:39:02
# ..       ...                 ...
# 697  twitter 2017-10-17 12:05:33
# 698  twitter 2017-10-17 09:37:03
# 699  twitter 2017-10-15 06:25:49
# 700  twitter 2017-10-13 08:35:52
# 701  twitter 2017-10-11 08:12:07
# 702  twitter 2017-10-10 14:31:38
# 703  twitter 2017-10-10 12:58:54
# 705  twitter 2017-10-07 06:58:09
# 706  twitter 2017-10-02 12:10:01
# 707  twitter 2017-09-30 20:42:32
# 708  twitter 2017-09-29 21:42:34
# 709  twitter 2017-09-26 21:18:05
# 710  twitter 2017-09-26 07:37:33
# 711  twitter 2017-09-25 20:59:48
# 712  twitter 2017-09-24 14:36:22
# 713  twitter 2017-09-19 18:57:59
# 714  twitter 2017-09-18 07:34:27
# 715  twitter 2017-09-17 07:57:13
# 716  twitter 2017-09-15 21:11:40
# 717  twitter 2017-09-14 17:04:01
# 718  twitter 2017-09-13 12:00:31
# 719  twitter 2017-09-12 10:53:30
# 720  twitter 2017-09-12 07:52:17
# 721  twitter 2017-09-11 16:28:37
# 723  twitter 2017-09-10 09:17:20
# 724  twitter 2017-09-06 19:50:21
# 725  twitter 2017-09-05 06:39:13
# 726  twitter 2017-08-29 20:24:27
# 727  twitter 2017-08-23 07:49:51
# 728  twitter 2017-08-21 21:21:54
#
#                                                Content Title  Comment_count  \
# 438  De volstrekte onlogica om te denken dat duizen...  Null            8.0
# 439  Massale inzet windmolens verstoort klimaat. Do...  Null            5.0
# 440  Dolfijnen gewoon in de Noordzee rond de TX-1. ...  Null           13.0
# 442  1% van onze elektriciteit komt nu uit windmole...  Null            8.0
# 443  Verder niks aan de hand hoor jongens. Gewoon d...  Null            4.0
# 444  Internationaal Hitteplan:-Zonnepanelen ipv dak...  Null            7.0
# 445  De nieuwe prioriteiten van @de_NVA:1. Windmole...  Null           15.0
# 446  Met alleen windmolens en zonnepanelen gaan we ...  Null           12.0
# 447  Wat knapt zo'n landschap daar van op hè? Mag w...  Null           95.0
# 450  Windmolens te land of in zee....waarover men i...  Null            0.0
# 451  H2 is zeer lucratief ja. Tenminste vanuit een ...  Null            0.0
# 452  Van gas los Wellicht nóg dommer beleid dan mil...  Null            3.0
# 453  De moslima's in burkini zijn als Don Quichot i...  Null           13.0
# 454  De #VVD wil het leefgenot van de Brabanders en...  Null            1.0
# 455  Nog een kleinigheidje wellicht: die 1500 km aa...  Null            2.0
# 456  89 windmolens 16miljard subsidie? Die stroom g...  Null            3.0
# 457  Misschien nog drie generaties Nederland dan is...  Null            5.0
# 459  Het volbouwen van de mooie Noordzee met windmo...  Null            0.0
# 460  Je kunt dit eigenlijk niet genoeg herhalen Win...  Null            3.0
# 461  Als je even wil lezen waar de vele #stroompann...  Null            4.0
# 462   Hadden we maar naar de groene jongens geluis...  Null            1.0
# 463  Ministerraad zette net licht finaal op groen v...  Null            1.0
# 464  Windmolens worden geproduceerd met oude energi...  Null           12.0
# 465  We gaan dus ons landschap verknoeien met #wind...  Null            3.0
# 466  Zojuist breed draagvlak in Staten van Gelderla...  Null            1.0
# 467  Hebben we oorlogen nodig voor #vooruitgang? Tr...  Null            8.0
# 468  De energietransitie moet duurzaam en betaalbaa...  Null            9.0
# 469  per jaar wordt er in Nederland evenveel kerosi...  Null            6.0
# 470  Minister Schouten en minister Wiebes spraken v...  Null            4.0
# 471  Het plan om in Duitsland windmolens te plaatse...  Null            2.0
# ..                                                 ...   ...            ...
# 697  Actievoerders willen keihard 'nee' van de Rabo...  Null            1.0
# 698  Op weg naar het noorden? Bij Green Planet in P...  Null            1.0
# 699  Prachtig gezicht deze ochtend in Flevoland. In...  Null            0.0
# 700  Hoeraaa....PVV leider Geert Wilders is plotsel...  Null            6.0
# 701  De 5 laatste kolencentrales vervangen door duu...  Null            6.0
# 702  Weert gaat windmolens zetten.  Op naar een CO2...  Null            1.0
# 703  Dit: kolencentrales dicht klimaatdoelen Parijs...  Null            2.0
# 705  De grootste liefhebbers van windmolens betalen...  Null            5.0
# 706  Windmolens en zonneparken? Dan volgt hier de r...  Null            7.0
# 707  Duitsland moet duizenden windmolens afbreken.A...  Null            8.0
# 708  Geen ¬  subsidie naar fossiel (Kamp 2015) & wi...  Null            1.0
# 709  Windmolens zijn eindelijk welkom in Amersfoort...  Null            2.0
# 710  Groenemorgen! @gem_Zutphen gaat drie windmolen...  Null            2.0
# 711  En maar vertellen dat je bezorgd bent om klima...  Null            1.0
# 712  IK KAN MET MIJN GEWONE VROUW-WOEDE DERTIG WIND...  Null            5.0
# 713  T'is eenvoudig: Duitsland heeft 26.000 windmol...  Null            2.0
# 714  Denemarken 5.000 windmolens Duitsland 26.000 w...  Null            6.0
# 715  Grappig luchthaven in zee kan niet vanwege vog...  Null           16.0
# 716  Trots op alweer een windmolenproject zonder en...  Null            6.0
# 717  Duitsland wordt wakker. Er mag geen bos meer g...  Null            4.0
# 718  Pech voor Twitter-pessimisten: windmolens draa...  Null            5.0
# 719  en 'toffe peer' Rutte op VVD congressen maar r...  Null            2.0
# 720  Dalende prijs windmolens op zee zet door. Hern...  Null            9.0
# 721  Gloeilampverbod uit 2009 was 'een grote zwende...  Null            7.0
# 723        Hollands glorie: windmolens in Kinderdijk!   Null            1.0
# 724  Ja joh. Paar zonnepanelen en windmolens erbij ...  Null            8.0
# 725  Raar fenomeen dat fossiele energiebedrijven al...  Null            6.0
# 726  Waarom zetten we Nederland niet vol windmolens...  Null            2.0
# 727  Burgers en alle politieke partijen in Diemen v...  Null            3.0
# 728   Verduurzamen willen de meeste burgers wel ma...  Null            3.0
#
#      Retweet_count  Polarity  Subjectivity  month  year  days_since_first
# 438           13.0  0.100000      0.500000      7  2018              4054
# 439           74.0  0.200000      0.550000      7  2018              4053
# 440           66.0  0.000000      0.700000      7  2018              4053
# 442           57.0  0.400000      0.575000      7  2018              4051
# 443           13.0  0.000000      0.400000      7  2018              4049
# 444           23.0  0.000000      0.100000      7  2018              4049
# 445           89.0 -0.175000      0.700000      7  2018              4048
# 446           24.0  0.000000      0.000000      7  2018              4047
# 447          245.0 -0.300000      0.500000      7  2018              4047
# 450           14.0  0.000000      0.000000      7  2018              4043
# 451           17.0  0.188333      0.620000      7  2018              4042
# 452           38.0 -0.005333      0.573667      7  2018              4040
# 453            9.0  0.150000      0.450000      7  2018              4039
# 454           16.0 -0.266667      0.550000      7  2018              4039
# 455           12.0 -0.050000      0.800000      7  2018              4038
# 456           50.0 -0.650000      0.900000      7  2018              4037
# 457           54.0  0.200000      0.750000      7  2018              4037
# 459           13.0  0.700000      1.000000      7  2018              4036
# 460           24.0 -0.250000      0.600000      7  2018              4036
# 461           26.0  0.200000      0.500000      7  2018              4036
# 462            9.0  0.150000      0.600000      7  2018              4033
# 463            6.0  0.150000      0.600000      7  2018              4031
# 464           92.0  0.066667      0.383333      7  2018              4031
# 465           24.0 -0.016667      0.461111      7  2018              4031
# 466            8.0 -0.216667      0.566667      7  2018              4029
# 467           16.0  0.125000      0.225000      7  2018              4028
# 468            4.0  0.075000      0.687500      6  2018              4021
# 469           88.0 -0.062500      0.400000      6  2018              4018
# 470           30.0  0.000000      0.000000      6  2018              4018
# 471           53.0  0.000000      0.000000      6  2018              4017
# ..             ...       ...           ...    ...   ...               ...
# 697           14.0  0.100000      0.700000     10  2017              3769
# 698            5.0 -0.250000      0.750000     10  2017              3769
# 699           10.0  1.000000      1.000000     10  2017              3767
# 700            5.0  0.117188      0.650000     10  2017              3765
# 701           15.0  0.025000      0.300000     10  2017              3763
# 702            5.0 -0.325000      0.650000     10  2017              3763
# 703           10.0  0.000000      0.100000     10  2017              3762
# 705           40.0  0.000000      0.000000     10  2017              3759
# 706           46.0  0.000000      0.000000     10  2017              3754
# 707           63.0  0.400000      0.400000      9  2017              3753
# 708           19.0  0.083333      0.750000      9  2017              3752
# 709            8.0  0.316667      0.633333      9  2017              3749
# 710            7.0  0.000000      0.000000      9  2017              3748
# 711           20.0 -0.100000      0.800000      9  2017              3748
# 712            8.0  0.000000      0.700000      9  2017              3747
# 713           26.0  0.433333      0.900000      9  2017              3742
# 714           18.0  0.000000      0.000000      9  2017              3740
# 715           17.0  0.600000      1.000000      9  2017              3739
# 716           40.0  0.350000      0.900000      9  2017              3738
# 717           35.0  0.300000      0.450000      9  2017              3737
# 718           15.0  0.375000      0.625000      9  2017              3735
# 719           15.0  0.600000      0.900000      9  2017              3734
# 720           16.0  0.000000      0.000000      9  2017              3734
# 721           42.0  0.183333      0.500000      9  2017              3734
# 723            7.0  0.000000      0.000000      9  2017              3732
# 724           12.0  0.000000      0.000000      9  2017              3729
# 725            9.0 -0.500000      1.000000      9  2017              3727
# 726           13.0 -0.150000      0.625000      8  2017              3721
# 727           21.0  0.000000      0.400000      8  2017              3714
# 728           15.0  0.000000      0.000000      8  2017              3713
#
# [264 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2569 entries, 0 to 2732
# Data columns (total 11 columns):
# Origin              2569 non-null object
# Timestamp           2569 non-null datetime64[ns]
# Content             2569 non-null object
# Title               2569 non-null object
# Comment_count       2569 non-null float64
# Retweet_count       2569 non-null float64
# Polarity            2569 non-null float64
# Subjectivity        2569 non-null float64
# month               2569 non-null int64
# year                2569 non-null int64
# days_since_first    2569 non-null int64
# dtypes: datetime64[ns](1), float64(4), int64(3), object(3)
# memory usage: 240.8+ KB

# %%
print(df_train.count(), df_test.count())
# Out:
# Origin              1888
# Timestamp           1888
# Content             1888
# Title               1888
# Comment_count       1888
# Retweet_count       1888
# Polarity            1888
# Subjectivity        1888
# month               1888
# year                1888
# days_since_first    1888
# dtype: int64 Origin              264
# Timestamp           264
# Content             264
# Title               264
# Comment_count       264
# Retweet_count       264
# Polarity            264
# Subjectivity        264
# month               264
# year                264
# days_since_first    264
# dtype: int64

# %%
# select features

# one-hot-encode month, to let the linear model recognize monthly seasonality

# features = ['month']

# ohe = OneHotEncoder(categorical_features=[0])

# x_train = ohe.fit_transform(df_train[features].astype(int))

# x_test = ohe.transform(df_test[features].astype(int))



# define targets

target = 'Polarity'

y_train = df_train[target]

y_test = df_test[target]



# # fit and aply linear regression model
import numpy as np

x_train = np.column_stack((df_train['month'], df_train['Subjectivity'])).astype(int)
x_test = np.column_stack((df_test['month'], df_test['Subjectivity'])).astype(int)
y_test = df_test[target]

model = LinearRegression()

model.fit(x_train, y_train)

pred_train = model.predict(x_train)

pred_test = model.predict(x_test)

df_test['predictions'] = pred_test

df_test.head()
# Out:
#       Origin           Timestamp  \
# 438  twitter 2018-07-29 06:30:00
# 439  twitter 2018-07-28 09:50:18
# 440  twitter 2018-07-27 15:19:38
# 442  twitter 2018-07-26 09:43:18
# 443  twitter 2018-07-24 09:34:32
#
#                                                Content Title  Comment_count  \
# 438  De volstrekte onlogica om te denken dat duizen...  Null            8.0
# 439  Massale inzet windmolens verstoort klimaat. Do...  Null            5.0
# 440  Dolfijnen gewoon in de Noordzee rond de TX-1. ...  Null           13.0
# 442  1% van onze elektriciteit komt nu uit windmole...  Null            8.0
# 443  Verder niks aan de hand hoor jongens. Gewoon d...  Null            4.0
#
#      Retweet_count  Polarity  Subjectivity  month  year  days_since_first  \
# 438           13.0       0.1         0.500      7  2018              4054
# 439           74.0       0.2         0.550      7  2018              4053
# 440           66.0       0.0         0.700      7  2018              4053
# 442           57.0       0.4         0.575      7  2018              4051
# 443           13.0       0.0         0.400      7  2018              4049
#
#      predictions
# 438     0.050197
# 439     0.050197
# 440     0.050197
# 442     0.050197
# 443     0.050197

# %%
df.corr()
# Out:
#                   Comment_count  Retweet_count  Polarity  Subjectivity  \
# Comment_count          1.000000       0.647040 -0.002840      0.072814
# Retweet_count          0.647040       1.000000  0.003935      0.048564
# Polarity              -0.002840       0.003935  1.000000      0.228086
# Subjectivity           0.072814       0.048564  0.228086      1.000000
# month                  0.014166       0.005847  0.019913     -0.001238
# year                   0.167124       0.190919  0.011599      0.152434
# days_since_first       0.171918       0.195411  0.014080      0.154934
#
#                      month      year  days_since_first
# Comment_count     0.014166  0.167124          0.171918
# Retweet_count     0.005847  0.190919          0.195411
# Polarity          0.019913  0.011599          0.014080
# Subjectivity     -0.001238  0.152434          0.154934
# month             1.000000 -0.225061         -0.117588
# year             -0.225061  1.000000          0.994013
# days_since_first -0.117588  0.994013          1.000000

# %%
# plt.plot(df_train['Timestamp'], pred_train, label='train predictions', linestyle='--', color='blue')

# plt.plot(df_train['Timestamp'], y_train, label='train actuals', linestyle='-', color='blue'

plt.scatter( df_test['month'], y_test,label='test actuals', linestyle='-', color='red')

plt.plot( df_test['month'], pred_test, label='test predictions', linestyle='--', color='blue')

plt.legend(loc='upper left', bbox_to_anchor=(1,1))

plt.xticks(rotation=30)

plt.ylabel(target)

plt.show()

# %%
from sklearn.metrics import r2_score
model.coef_

r2_score(df_test['Polarity'], pred_test)
# Out:
# -0.00029980336436219446
